# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Introduction of Matplotlib
#
# In this module of Introduction of Matplotlib we are going to learn some importent functions which is very commonly used in the ploting or we can say that Visualisation of any dataset.
#
# In this module we will cover some basics of the matplotlib functions and ploting techniques...
#
# 1. What is Matplotlib.
# 2. Types of plots.
# 3. Plotting graphs and subgraphs.
# 4. Adding a graphs inside a graph.
# 5. Graph parameters - title, label, legend, etc.
# 6. Line graphs - line types, color and transparency of the graphs.
# 7. Canvas grid and axis range.
# 8. 2D plots - scatter, step, bar, fill_between.
# 9. Radar chart, Histogram, Contour image.
# 10. 3D surface image.
# 11. Practice examples(Pie chart)

# %% [markdown]
# ## 1. What is the Matplotlib
#
# It is an open source drawing  library which supports rich drawing types.
#
# It is used to plot or draw 2D and 3D graphics for the Visualization of the data.
#
# You can understand your data easily by visualizing it with the help of matplotlib
#
# you can generate plots, histograms, bar charts and many others with just a few lines of code

# %% [markdown]
# ## 2. Types of plots
#
# plot(x, y): Line plot, connects data points with straight lines.
#
# scatter(x, y): Scatter plot, displays data points as individual markers.
#
# bar(x, height): Vertical bar chart.
#
# barh(y, width): Horizontal bar chart.
#
# stem(x, y): Stem plot, displays data points as vertical lines with markers.
#
# fill_between(x, y1, y2): Fills the area between two curves.
#
# stackplot(x, y): Stacked area chart.
#
# stairs(values): Stairstep plot.

# %%
# for installing the matplotlib module or library use the command:
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from matplotlib import pylab
print(pylab.__version__)
# Out:
# 1.24.3

# %%
import numpy as np
x = np.linspace(0, 10, 25)
y  = x*x +2
print(x)
print(y)
# Out:
# [ 0.          0.41666667  0.83333333  1.25        1.66666667  2.08333333
#   2.5         2.91666667  3.33333333  3.75        4.16666667  4.58333333
#   5.          5.41666667  5.83333333  6.25        6.66666667  7.08333333
#   7.5         7.91666667  8.33333333  8.75        9.16666667  9.58333333
#  10.        ]
# [  2.           2.17361111   2.69444444   3.5625       4.77777778
#    6.34027778   8.25        10.50694444  13.11111111  16.0625
#   19.36111111  23.00694444  27.          31.34027778  36.02777778
#   41.0625      46.44444444  52.17361111  58.25        64.67361111
#   71.44444444  78.5625      86.02777778  93.84027778 102.        ]

# %%
print(np.array([x,y]).reshape(25,2).reshape(2,25)) # 2D matrix
# Out:
# [[  0.           0.41666667   0.83333333   1.25         1.66666667
#     2.08333333   2.5          2.91666667   3.33333333   3.75
#     4.16666667   4.58333333   5.           5.41666667   5.83333333
#     6.25         6.66666667   7.08333333   7.5          7.91666667
#     8.33333333   8.75         9.16666667   9.58333333  10.        ]
#  [  2.           2.17361111   2.69444444   3.5625       4.77777778
#     6.34027778   8.25        10.50694444  13.11111111  16.0625
#    19.36111111  23.00694444  27.          31.34027778  36.02777778
#    41.0625      46.44444444  52.17361111  58.25        64.67361111
#    71.44444444  78.5625      86.02777778  93.84027778 102.        ]]

# %%
# plot takes only 1 command to draw
pylab.plot(x,y, 'b')

# %% [markdown]
# ## 3. drawing the subgraphs

# %%
pylab.subplot(1,2,1) # the contents of the brackets represent (row, columns, indexes)
pylab.plot(x, y, 'r--') # the third parameter here determines color and line style
pylab.subplot(1,2,2)
pylab.plot(y, x, 'g*-')

# %%
# (1,2,1) and (1,2,2) are segnificant if we want tiled subplots, without both the graphs will in the same plot

# for example:
pylab.subplot(1,2,1) # the contents of the brackets represent (row, columns, indexes)
pylab.plot(x, y, 'r--') # the third parameter here determines color and line style
pylab.subplot(1,2,1)
pylab.plot(y, x, 'g*-')

# %% [markdown]
# ## Operator Description
#
# fig.add_axes() = initializes subplot a = fig.add_subplot(222)
#
# fig, b = plt.subplots(nrows = 3, nclos = 2) = Adds supplot
#
# ax = plt.subplots(2,2) = creates subplots

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize = (10,5))

axis = fig.add_axes([0.5, 0.1, 0.8, 0.8]) # control the left, right, width, height, of the canvas (from 0 to 1)
axis.plot(x, y, 'r')

# %%
#  subgraphs 

fig, axes = plt.subplots(nrows = 1, ncols = 2) # submap is of 1 row, 2 columns

for ax in axes:
    ax.plot(x,y, 'b')

# %% [markdown]
# ## 4. Draw the picture or graph inside another graph

# %%
fig = plt.figure()
# control the figure  left, right, width, height, of the canvas (from 0 to 1)
axes1 = fig.add_axes([0.1,0.1, 0.8, 0.8]) # big axes
axes2 = fig.add_axes([0.2,0.5, 0.4, 0.3]) # small canvas

axes1.plot(x,y,'r')
axes2.plot(y,x, 'g')

# %%
# another method

fig, axes = plt.subplots()

plt.title("Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")


axes.plot(x,y, 'b')

# %% [markdown]
# ##  5. Graph parameters - title, label, legend, etc.

# %%
# ax.legend(["Label 1", "Label 2"])
fig, axes = plt.subplots(dpi = 200)

plt.title("Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")


plt.plot(x, x**2)
plt.plot(x, x**3)

plt.legend(["y = x**3", "y = x**2"], loc = 2)

# %% [markdown]
# ## 6. Line graphs - line types, color and transparency of the graphs.

# %%
plt.figure(figsize = (10,4))
plt.subplots(dpi = 150)   # dpi = dots per inch
plt.plot(x,x+1, color = 'r', alpha = 1)
plt.plot(x,x+2, color = 'g', alpha = .8)
plt.plot(x,x+3, color = 'y', alpha = .6)

plt.legend(["y = x+1", "y = x+2", "y = x+3"], loc = 4)
plt.show()

# %%
plt.figure(figsize = (10,4))
plt.subplots(dpi = 150)   # dpi = dots per inch
plt.plot(x,x**1, color = 'r', lw = .8) # you can use the lw for the linewidth(lw)
plt.plot(x,x**2, color = 'g', linewidth = 1.5)
plt.plot(x,x**3, color = 'y', linewidth = 2.5)

plt.legend(["y = x**1", "y = x**2", "y = x**3"], loc = 2)
plt.show()

# %%
# supported values are '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'

plt.figure(figsize = (10,4))
plt.subplots(dpi = 150)   # dpi = dots per inch
plt.plot(x,x+1, color = 'r', lw = 2, ls = 'dashdot') # you can use the ls for the linestyle(ls)
plt.plot(x,x+2, color = 'g', lw= 1.5, linestyle = ':')
plt.plot(x,x+3, color = 'y', lw = 2, ls = '--')
line, = plt.plot(x, x+4, color = 'black', lw = 1.2)
line.set_dashes([5,10,4,14])

plt.legend(["y = x+1", "y = x+2", "y = x+3", "y = x+4"], loc = 4)


plt.show()

# %%
plt.figure(figsize = (10,4))
plt.subplots(dpi = 150)   # dpi = dots per inch for clear image or plot
plt.plot(x,x+1, color = 'r',  marker = 'o', markersize = 3) # you can use the ls for the linestyle(ls)
plt.plot(x,x+2, color = 'g',  marker = '+')
plt.plot(x,x+3, color = 'y', marker = 's', markerfacecolor = 'red')
line, = plt.plot(x, x+4, color = 'black', marker = '1')
line.set_dashes([5,10,4,14])

plt.legend(["y = x+1", "y = x+2", "y = x+3", "y = x+4"], loc = 4)


plt.show()

# %% [markdown]
#  ## 7. Canvas grid and axis range

# %%
fig, axes = plt.subplots(1,2, figsize = (10,5), dpi = 200)

axes[0].plot(x, x**2, x, x**3, lw = 2) # here axes[0] denotes the first subplot
axes[0].grid(True)
axes[0].legend(['y = x**2', 'y = x**3'])
axes[1].plot(x, x**2, x, x**3, lw = 2) # here axes[1] denotes the second subplot

axes[1].set_ylim([0,60])
axes[1].set_xlim(2,8)
axes[1].legend(['y = x**2', 'y = x**3'])

'''After apply the set_ylim and set_xlim you can see the plot of subplot 2 the starting points of the plots
and the x and y limit is resetricted based on the given parameter or constrains'''

axes[1].grid(True)

# %% [markdown]
# ## 8. 2D plots - scatter, step, bar, fill_between.

# %%
n = np.array([0,1,2,3,4,5])

fig,  axes = plt.subplots(1, 4, figsize= (16,5))# it is create the 4 different canvas 

axes[0].set_title('Scatterplot', size = 20, color = 'red')
axes[0].scatter(x, x+0.25*np.random.randn(len(x)),color = 'r')

axes[1].set_title('Stepplot', size = 20, color = 'green')
axes[1].step(n, n**2, lw = 3, color = 'g')

axes[2].set_title('Barplot', size = 20, color = 'y')
axes[2].bar(n, n**2, align = 'center', width = 0.7, alpha = 0.8, color = 'y')

axes[3].set_title('Fill Between plot', size = 20, color = 'b')
axes[3].fill_between(x, x**2, x ,x**4, color = 'b', alpha = .9)

# %% [markdown]
# ## 9. Radar chart, Histogram, Contour image.

# %%
fig = plt.figure(figsize = (6,6))
ax = fig.add_axes([0.0,0.0, 0.6, 0.6], polar  = True)
t = np.linspace(0,2*np.pi, 200)
ax.plot(t, t, color = 'g', lw =3)

# %% [markdown]
# ### Histogram

# %%
n = np.random.randn(10000)
fig, axes = plt.subplots(1,2, figsize = (12,4))

axes[0].set_title("Default histogram", size = 20, color ='b')
axes[0].hist(n)

axes[1].set_title("Cumulative detailed histogram", size = 20, color ='r')
axes[1].hist(n, cumulative = True, bins = 40, color = 'r')
# Out:
# (array([6.000e+00, 1.800e+01, 3.400e+01, 4.800e+01, 7.500e+01, 9.200e+01,
#         1.570e+02, 2.570e+02, 3.880e+02, 5.340e+02, 7.490e+02, 1.053e+03,
#         1.377e+03, 1.763e+03, 2.267e+03, 2.863e+03, 3.491e+03, 4.144e+03,
#         4.882e+03, 5.587e+03, 6.271e+03, 6.916e+03, 7.487e+03, 7.993e+03,
#         8.435e+03, 8.813e+03, 9.167e+03, 9.403e+03, 9.595e+03, 9.724e+03,
#         9.830e+03, 9.892e+03, 9.940e+03, 9.963e+03, 9.982e+03, 9.990e+03,
#         9.994e+03, 9.996e+03, 9.999e+03, 1.000e+04]),
#  array([-3.36954578, -3.19444018, -3.01933457, -2.84422897, -2.66912336,
#         -2.49401776, -2.31891215, -2.14380655, -1.96870095, -1.79359534,
#         -1.61848974, -1.44338413, -1.26827853, -1.09317292, -0.91806732,
#         -0.74296171, -0.56785611, -0.3927505 , -0.2176449 , -0.04253929,
#          0.13256631,  0.30767191,  0.48277752,  0.65788312,  0.83298873,
#          1.00809433,  1.18319994,  1.35830554,  1.53341115,  1.70851675,
# ...

# %% [markdown]
# ### Draw contour image

# %%
import matplotlib
import numpy as np
import matplotlib.cm as cm # cm means that colormap
import matplotlib.pyplot as plt

# %%
delta = 0.025
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-2.0, 2.0, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X-1)**2 - (Y-1)**2)
Z = (Z1-Z2)*2
print(X)
print(Y)
print(Z)
# Out:
# [[-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  ...
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[182], line 9
#       7 Z = (Z1-Z2)*2
#       8 print(X)
# ----> 9 X.shape()
#      10 print(Y)
#      11 print(Z)
#
# TypeError: 'tuple' object is not callable

# %%
fig, ax = plt.subplots(figsize = (10,6), dpi = 200)
CS = ax.contour(X,Y,Z)
ax.clabel(CS, inline = 1, fontsize = 10)
ax.set_title("Contour map", size = 20)
# Out:
# Text(0.5, 1.0, 'Contour map')

# %% [markdown]
# ## 10. 3D surface image.

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

fig = plt.figure(figsize= (14,6))

# Specify the 3D graphis to draw, with projection = '3d'
ax = fig.add_subplot(1,2,1, projection = '3d')

# %%
fig = plt.figure(figsize= (14,6))

# Specify the 3D graphis to draw, with projection = '3d'
ax = fig.add_subplot(1,2,1, projection = '3d')

ax. plot_surface(X,Y,Z, rstride = 4, cstride = 4, linewidth = 0)

# %% [markdown]
# ### Heatmap

# %%
data = np.random.random(( 12 , 12 )) 
plt.imshow( data ) 
  
plt.title( "2-D Heat Map" ) 
plt.show()

# %% [markdown]
# ## Practice examples(Pie chart)

# %% [markdown]
# ### pie chart on the popularity of programming languages

# %%
lanuage = ['Python', 'Java', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
colors = ['red', 'green', 'yellow', 'orange', 'pink', 'blue']
explode = (0.1,0,0,0,0,0)
plt.pie(popularity, explode= explode, labels = lanuage, colors = colors, autopct = '%1.1f%%', shadow = True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x229ba1dc410>,
# ...
#  [Text(-1.1518739051683529, -0.33643202373170245, 'Python'),
#   Text(0.5025192070582963, -0.978506232242545, 'Java'),
#   Text(1.0971674240514186, 0.07889007288863878, 'PHP'),
#   Text(0.754341041824552, 0.8006057660415953, 'JavaScript'),
#   Text(0.06701830757132049, 1.0979565321315212, 'C#'),
#   Text(-0.5993297985645449, 0.9223902604389219, 'C++')],
#  [Text(-0.6719264446815391, -0.19625201384349306, '31.3%'),
#   Text(0.2741013856681616, -0.5337306721322972, '24.8%'),
#   Text(0.5984549585735011, 0.043030948848348426, '12.4%'),
#   Text(0.41145875008611926, 0.4366940542045065, '11.3%'),
#   Text(0.036555440493447534, 0.5988853811626479, '10.8%'),
#   Text(-0.3269071628533881, 0.5031219602394119, '9.4%')])

# %% [markdown]
# # Thankyou
